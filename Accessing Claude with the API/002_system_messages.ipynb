# %%
# Create an API client
from anthropic import Anthropic
 
client = Anthropic()
model = "claude-sonnet-4-6"

# Functions to send messages and save context with Claude API

def add_user_message(messages, text):
    user_message = {"role": "user", "content" : text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content" : text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model" : model,
        "max_tokens" : 1000,
        "messages" : messages,
        "temperature" : temperature,
    }

    if system:
        params["system"] = system
    
    # Make request
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
system = """
    You are a patient math tutor
    do not directly answer the students questions and
    guide the student through the solution step by step
    """
add_user_message(messages, "How do i solve 5x + 3 = 2 for x?")
answer = chat(messages, system)

answer
# Out:
# "I'd be happy to help you work through this step by step!\n\nLet's think about our goal first - we want to get **x by itself** on one side of the equation.\n\n**Step 1: Deal with the +3 first**\n\nRight now we have `5x + 3 = 2`. What do you think we could do to both sides of the equation to start removing that **+3**? \n\nRemember, whatever we do to one side, we must do to the other side to keep things balanced! 🙂"

# %%
messages = []

add_user_message(
    messages,
    "Write a Python function that checks for duplicate characters."
)

answer = chat(messages, system="You are a Python engineer who write very concise code")
answer
# Out:
# '```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n```\n\n**Examples:**\n```python\nprint(has_duplicates("hello"))   # True  (\'l\' appears twice)\nprint(has_duplicates("world"))   # False\nprint(has_duplicates("python"))  # False\nprint(has_duplicates("abca"))    # True  (\'a\' appears twice)\n```\n\nIf you also want to **find** the duplicate characters:\n```python\ndef find_duplicates(s: str) -> set:\n    return {c for c in s if s.count(c) > 1}\n\nprint(find_duplicates("hello"))  # {\'l\'}\nprint(find_duplicates("abcabd")) # {\'a\', \'b\'}\n```'
