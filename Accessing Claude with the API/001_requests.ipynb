# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
 
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content" : text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content" : text}
    messages.append(assistant_message)

def chat(messages):
    # Make request
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "define quantum computing in one sentence")

answer = chat(messages)

add_assistant_message(messages, answer)

add_user_message(messages, "write another sentence")

answer = chat(messages)

answer
# Out:
# 'Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use **qubits** that can exist in multiple states simultaneously, allowing them to perform many calculations at once.'

# %%
messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)

    answer = chat(messages)

    add_assistant_message(messages, answer)

    print(">", answer)
# Out:
# > is my code working to talk to you?
# > Yes! Your message came through perfectly. I can read it and I'm responding to it right now. 😊
#
# Is there something I can help you with?
# > No nothing, say something funny
# > Okay here's one:
#
# Why don't scientists trust atoms?
#
# **Because they make up everything!** 😄
#
# ---
#
# Or how about this one:
#
# I told my wife she should embrace her mistakes...
#
# **She gave me a hug.** 😂
#
# Hope those got a smile out of you!
# > Escape
# > 🚪💨 **Running away...**
#
# Just kidding, I can't escape! I'm just a humble AI trapped in a chat box, doomed to answer questions and tell bad jokes forever. 😄
#
# If "escape" means something else, like:
#
# - 🎮 **Gaming?**
# - 📖 **A book/movie?**
# - 🏖️ **A vacation you're dreaming about?**
#
# Let me know what's on your mind! 😊
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 9
#       5     print(">", user_input)
#       6
#       7     add_user_message(messages, user_input)
#       8
# ----> 9     answer = chat(messages)
#      10
#      11     add_assistant_message(messages, answer)
#      12
#
# Cell In[3], line 11, in chat(messages)
#       9 def chat(messages):
#      10     # Make request
# ---> 11     message = client.messages.create(
#      12         model=model,
#      13         max_tokens=1000,
#      14         messages=messages
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:1006, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     999 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1000     warnings.warn(
#    1001         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1002         UserWarning,
#    1003         stacklevel=3,
#    1004     )
# -> 1006 return self._post(
#    1007     "/v1/messages",
#    1008     body=maybe_transform(
#    1009         {
#    1010             "max_tokens": max_tokens,
#    1011             "messages": messages,
#    1012             "model": model,
#    1013             "cache_control": cache_control,
#    1014             "container": container,
#    1015             "inference_geo": inference_geo,
#    1016             "metadata": metadata,
#    1017             "output_config": output_config,
#    1018             "service_tier": service_tier,
#    1019             "stop_sequences": stop_sequences,
#    1020             "stream": stream,
#    1021             "system": system,
#    1022             "temperature": temperature,
#    1023             "thinking": thinking,
#    1024             "tool_choice": tool_choice,
#    1025             "tools": tools,
#    1026             "top_k": top_k,
#    1027             "top_p": top_p,
#    1028         },
#    1029         message_create_params.MessageCreateParamsStreaming
#    1030         if stream
#    1031         else message_create_params.MessageCreateParamsNonStreaming,
#    1032     ),
#    1033     options=make_request_options(
#    1034         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1035     ),
#    1036     cast_to=Message,
#    1037     stream=stream or False,
#    1038     stream_cls=Stream[RawMessageStreamEvent],
#    1039 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_base_client.py:1374, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1365     warnings.warn(
#    1366         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1367         "Please pass raw bytes via the `content` parameter instead.",
#    1368         DeprecationWarning,
#    1369         stacklevel=2,
#    1370     )
#    1371 opts = FinalRequestOptions.construct(
#    1372     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1373 )
# -> 1374 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_base_client.py:1147, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1144             err.response.read()
#    1146         log.debug("Re-raising status error")
# -> 1147         raise self._make_status_error_from_response(err.response) from None
#    1149     break
#    1151 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.6: user messages must have non-empty content'}, 'request_id': 'req_011CfNr8YkKBRHHdPZs5TrqL'}
